# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import missingno as msno
import seaborn as sns
import pandas as pd

# %%
os.chdir("/home/aadityasharma/Desktop/Aaditya_Sharma_Trainee_Hestabit/Week_6")
print(os.getcwd())
# Out:
# /home/aadityasharma/Desktop/Aaditya_Sharma_Trainee_Hestabit/Week_6

# %%
DATA_PATH = "src/data/processed/diabetes_clean.csv"
print(DATA_PATH)
# Out:
# src/data/processed/diabetes_clean.csv

# %%
df = pd.read_csv(DATA_PATH)
df.head()
df.describe()
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
cols = df.columns.difference(['Outcome','Pregnancies'])
df[cols] = df[cols].replace(0, np.nan)

# %%
plt.figure(figsize=(8,6))
msno.bar(df)
plt.show()

# %%
plt.figure(figsize=(8,6))
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.show()

# %%
plt.figure(figsize=(8,6))
df["Outcome"].value_counts().plot(kind="bar")
plt.show()

# %%
numeric_cols=df.select_dtypes(include="number").columns
df[numeric_cols].hist(figsize=(20,10), bins=30)
plt.show()
